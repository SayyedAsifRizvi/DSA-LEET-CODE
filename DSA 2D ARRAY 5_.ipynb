# %% [markdown]
# ![Screenshot%202023-06-27%20153959.png](attachment:Screenshot%202023-06-27%20153959.png)

# %%
CODE:
class Solution:
    def construct2DArray(self, original: List[int], r: int, c: int) -> List[List[int]]:
        if len(original) == r*c:
            res = [[0 for c in range(c)] for r in range(r)]
            idx = 0
            for i in range(r):
                for j in range(c):
                    res[i][j] = original[idx]
                    idx +=1
            return res
        return None
LINK:https://leetcode.com/problems/convert-1d-array-into-2d-array/description/

# %% [markdown]
# ![Screenshot%202023-06-27%20154011.png](attachment:Screenshot%202023-06-27%20154011.png)

# %%
CODE:
class Solution:
    def arrangeCoins(self, n: int) -> int:
        left,right=1,n
        while left<=right:
            mid=(right+left)//2
            num=(mid/2)*(mid+1)
            if num<=n:
                left=mid+1
            else:
                right=mid-1
        return right
LINK:https://leetcode.com/problems/arranging-coins/description/

# %% [markdown]
# ![Screenshot%202023-06-27%20154020.png](attachment:Screenshot%202023-06-27%20154020.png)

# %%
CODE:
class Solution:
    def sortedSquares(self, nums: List[int]) -> List[int]:
        
        # Two Pointer Approach
        n = len(nums)
        l, r = 0, n - 1
        k = n - 1
        ans = [0] * n
        while k >= 0:
            if abs(nums[l]) > nums[r]:
                ans[k] = nums[l] * nums[l]
                l += 1
            else:
                ans[k] = nums[r] * nums[r]
                r -= 1
            k -= 1
        return ans
LINK:https://leetcode.com/problems/squares-of-a-sorted-array/description/

# %% [markdown]
# 💡 **Question 4**
#
# Given two **0-indexed** integer arrays nums1 and nums2, return *a list* answer *of size* 2 *where:*
#
# - answer[0] *is a list of all **distinct** integers in* nums1 *which are **not** present in* nums2*.*
# - answer[1] *is a list of all **distinct** integers in* nums2 *which are **not** present in* nums1.
#
# **Note** that the integers in the lists may be returned in **any** order.
#
# **Example 1:**
#
# **Input:** nums1 = [1,2,3], nums2 = [2,4,6]
#
# **Output:** [[1,3],[4,6]]
#
# **Explanation:**
#
# For nums1, nums1[1] = 2 is present at index 0 of nums2, whereas nums1[0] = 1 and nums1[2] = 3 are not present in nums2. Therefore, answer[0] = [1,3].
#
# For nums2, nums2[0] = 2 is present at index 1 of nums1, whereas nums2[1] = 4 and nums2[2] = 6 are not present in nums2. Therefore, answer[1] = [4,6].

# %%
CODE:
class Solution:
    def findDifference(self, nums1: List[int], nums2: List[int]) -> List[List[int]]:

        # define set to store elements
        s1 = set(nums1)
        s2 = set(nums2)

        # define output
        out = [[],[]]

        # adding the elements to output if not contains in the set
        for i in s1:
            if i not in s2:  
                out[0].append(i)
        for i in s2:
            if i not in s1:
                out[1].append(i)
        
        return out
LINK:https://leetcode.com/problems/find-the-difference-of-two-arrays/description/

# %% [markdown]
# ![Screenshot%202023-06-27%20154044.png](attachment:Screenshot%202023-06-27%20154044.png)

# %%
CODE:
class Solution:
        def findTheDistanceValue(self, arr1: List[int], arr2: List[int], d: int) -> int:
        res, buckets = 0, dict() # (minVa, maxVal)
        
        def getKey(val):
            return val // d
        
        def addVal(val):
            key = getKey(val)
            #save only min and max value in bucket, others values not
            if key in buckets:
                if buckets[key][0] > val: buckets[key][0] = val
                elif buckets[key][1] < val: buckets[key][1] = val
            else:
                buckets[key] = [val, val]
        
        #initialize buckets     
        for val in arr2: addVal(val)

        for val in arr1:
            key = getKey(val)
            if key in buckets: continue #in one bucket all values x < d
            #check sibling buckets
            if key - 1 in buckets and val - buckets[key-1][1] <= d: continue #maxVal from the left side is nearest
            if key + 1 in buckets and buckets[key+1][0] - val <= d: continue #minVal from the right side is nearest
            res += 1

        return res
LINK:https://leetcode.com/problems/find-the-distance-value-between-two-arrays/description/

# %% [markdown]
# ![Screenshot%202023-06-27%20154053.png](attachment:Screenshot%202023-06-27%20154053.png)

# %%
CODE:
class Solution:
    def findDuplicates(self, nums: List[int]) -> List[int]:
        result = []
        
        for i in range(len(nums)):
            index = abs(nums[i])-1
            if nums[index] < 0:
                result.append(index+1)
            else:
                nums[index] = -nums[index]
                
        return result
LINK:https://leetcode.com/problems/find-all-duplicates-in-an-array/description/

# %% [markdown]
# ![Screenshot%202023-06-27%20154101.png](attachment:Screenshot%202023-06-27%20154101.png)

# %%
CODE:
class Solution:
    def findMin(self, nums: List[int]) -> int:
        l, r = 0, len(nums) - 1

        while l < r:
            m = l + (r - l)

            if nums[m] > nums[r]:
                l = m + 1
             
            else:
                 r = m 

        return nums[l]    
LINK: https://leetcode.com/problems/find-minimum-in-rotated-sorted-array/description/

# %% [markdown]
# ![Screenshot%202023-06-27%20154110.png](attachment:Screenshot%202023-06-27%20154110.png)

# %%
CODE:
class Solution:
    def findOriginalArray(self, changed: List[int]) -> List[int]:
        
        """
        The idea is to:
            1st sort the numbers
            2nd Create a counter to save the frequency of each number
            3nd iterate the array and for each number check if the double exists.
            4rd after taking len(changed) // 2 numbers return the answer
            
        Time complexity: O(nlog(n)) 
        Space complexity: O(n)
        
        """
        
        
        if len(changed) % 2 != 0: # If there are not even amount the numbers there is no solution.
            return []
        
        changed.sort()
        
        c = Counter(changed) # The counter is needed because we have 0s
        
        answer = []
        for num in changed:
            if num in c and c[num] >= 1: # Check if the number is available (we may have taken it before)
                c[num] -= 1 # we mark the number as used by decreasing the counter (only needed for the zeros)
                if (num * 2) in c and c[(num * 2)] >= 1: # Take the one that doubles it if exists
                    answer.append(num)
                    c[num*2] -= 1 # The number has been taken.
            
            if len(answer) == len(changed) // 2:
                return answer
        
        return []
                
LINK:https://leetcode.com/problems/find-original-array-from-doubled-array/description/
